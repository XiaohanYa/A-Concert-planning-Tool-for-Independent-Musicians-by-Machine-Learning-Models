# %% [markdown]
# # Summary of This Notebook

# %% [markdown]
# In this notebook, our main goal is to prepare our trainning and testing datasets by combining all the the information from Last.fm, Seatgeek and City.Data. In order to keep trainning and testing separated, we didn't do any normalization here. Nonetheless, we unified some string format and drop all the NAs.

# %% [markdown]
# # 1. Connect to Database

# %%
import numpy as np
import matplotlib.pyplot as plt
import MySQLdb as mdb
import pandas as pd
# %matplotlib inline

# %%
con = mdb.connect(host = 'your IP', 
                  user = 'root',
                  database = 'My_Project',
                  passwd = '*****', 
                  charset='utf8', use_unicode=True);

# %% [markdown]
# # 1.1 Import data from seatgeek_artist

# %%
cur = con.cursor(mdb.cursors.DictCursor)
cur.execute('''SELECT * FROM seatgeek_artists 
            ORDER BY popularity DESC 
            ''')
artists = cur.fetchall()
cur.close()

artists = pd.DataFrame.from_records(artists)
print(artists.shape)
artists.head()
# Out:
# (5925, 3)
#          artist                              genres popularity
# 0  taylor-swift              country/pop/rock/folk/       0.89
# 1    charli-xcx                           pop/rock/       0.88
# 2    ed-sheeran                      pop/rock/folk/       0.88
# 3   snow-patrol  pop/rock/alternative/classic-rock/       0.88
# 4  eric-clapton        pop/rock/blues/classic-rock/       0.87

# %%
artists.columns = ["artist","genres", "concert_popularity"]
print(artists.shape)
artists.head()
# Out:
# (5925, 3)
#          artist                              genres concert_popularity
# 0  taylor-swift              country/pop/rock/folk/               0.89
# 1    charli-xcx                           pop/rock/               0.88
# 2    ed-sheeran                      pop/rock/folk/               0.88
# 3   snow-patrol  pop/rock/alternative/classic-rock/               0.88
# 4  eric-clapton        pop/rock/blues/classic-rock/               0.87

# %% [markdown]
# # 1.2 Import data from lastfm_cleaned

# %% [markdown]
# Since the formatting of artists' names in Last.fm is different from the formatting of Seatgeek, we unified the format by getting the lowercase of names and replace space with "-".

# %%
cur = con.cursor(mdb.cursors.DictCursor)
cur.execute('''SELECT * FROM lastfm
            
            ''')
lastfm = cur.fetchall()
cur.close()

# %%
lastfm = pd.DataFrame.from_records(lastfm).drop(columns = ["image_url"])

# %%
print(lastfm.shape)
lastfm.head()
# Out:
# (10563, 2)
#                 artist  playcount
# 0                  !!!    9821243
# 1  "Weird Al" Yankovic   16580264
# 2          $uicideboy$   13202244
# 3         'Til Tuesday     832931
# 4             (G)I-DLE     893650

# %%
lastfm["artist"] = lastfm["artist"].apply(lambda x: x.replace(" ", "-"))
lastfm["artist"] = lastfm["artist"].apply(lambda x: x.lower())
artist_name_list = lastfm["artist"]
artist_name_list[:5]
# Out:
# 0                    !!!
# 1    "weird-al"-yankovic
# 2            $uicideboy$
# 3           'til-tuesday
# 4               (g)i-dle
# Name: artist, dtype: object

# %%
lastfm.sort_values(by = "playcount",ascending=False).head(10)
# Out:
#                      artist  playcount
# 8896            the-beatles  505428022
# 7438              radiohead  490269805
# 1937               coldplay  354878559
# 6477                   muse  338136080
# 594          arctic-monkeys  323595920
# 7219             pink-floyd  306576636
# 7531  red-hot-chili-peppers  288558091
# 5445            linkin-park  288314785
# 5197              lady-gaga  273827943
# 6134              metallica  273444318

# %%
lastfm.sort_values(by = "playcount",ascending=True).head(10)
# Out:
#                           artist  playcount
# 5900                 mark-souzek       3190
# 5379        life-below-elephants       3350
# 9320                 the-sandbox       3363
# 10135  will-butler-vs-the-knocks       3614
# 4187       international-special       3679
# 5430            limestone-quarry       3866
# 7552                 réka-ioescu       3875
# 8584                  subtrailss       3889
# 10396                   zephyros       3953
# 8759                 taz-&-meeks       4212

# %% [markdown]
# # 1.3 Import data from seatgeek_concerts

# %%
cur = con.cursor(mdb.cursors.DictCursor)
cur.execute('''SELECT * FROM seatgeek_concerts
            
            ''')
concerts = cur.fetchall()
cur.close()

# %%
concerts = pd.DataFrame.from_records(concerts)
concerts.head()
# Out:
#                                       address    artist  average_price  \
# 0  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 1  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 2  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 3  1151 North High Street, Columbus, OH 43201  10-years          179.0
# 4  1151 North High Street, Columbus, OH 43201  10-years          124.0
#
#   concert_date  good_deals  highest_price  latitude  longitude  lowest_price  \
# 0   2018-11-28         NaN            NaN        40        -83           NaN
# 1   2018-12-08         NaN            NaN        36        -84           NaN
# 2   2018-12-15         NaN            NaN        30        -86           NaN
# 3   2018-12-28         NaN          584.0        40        -83         114.0
# 4   2018-12-29         NaN          584.0        41        -85          58.0
#
#           update_time                 venue
# 0 2018-11-06 04:39:04  skully's-music-diner
# 1 2018-11-06 04:39:04  skully's-music-diner
# 2 2018-11-06 04:39:04  skully's-music-diner
# 3 2018-11-06 04:39:04  skully's-music-diner
# 4 2018-11-06 04:39:04  skully's-music-diner

# %%
concerts["city"] = concerts['address'].str.split(',').str[1]
concerts["city"] = concerts["city"].apply(lambda x: x.replace(" ", ""))
print(concerts.shape)
concerts.head()
# Out:
# (16981, 12)
#                                       address    artist  average_price  \
# 0  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 1  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 2  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 3  1151 North High Street, Columbus, OH 43201  10-years          179.0
# 4  1151 North High Street, Columbus, OH 43201  10-years          124.0
#
#   concert_date  good_deals  highest_price  latitude  longitude  lowest_price  \
# 0   2018-11-28         NaN            NaN        40        -83           NaN
# 1   2018-12-08         NaN            NaN        36        -84           NaN
# 2   2018-12-15         NaN            NaN        30        -86           NaN
# 3   2018-12-28         NaN          584.0        40        -83         114.0
# 4   2018-12-29         NaN          584.0        41        -85          58.0
#
#           update_time                 venue      city
# 0 2018-11-06 04:39:04  skully's-music-diner  Columbus
# 1 2018-11-06 04:39:04  skully's-music-diner  Columbus
# 2 2018-11-06 04:39:04  skully's-music-diner  Columbus
# 3 2018-11-06 04:39:04  skully's-music-diner  Columbus
# 4 2018-11-06 04:39:04  skully's-music-diner  Columbus

# %%
concerts.drop(columns = ["update_time"],inplace = True)
print(concerts.shape)
total_concerts = concerts
total_concerts.head()
# Out:
# (16981, 11)
#                                       address    artist  average_price  \
# 0  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 1  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 2  1151 North High Street, Columbus, OH 43201  10-years            NaN
# 3  1151 North High Street, Columbus, OH 43201  10-years          179.0
# 4  1151 North High Street, Columbus, OH 43201  10-years          124.0
#
#   concert_date  good_deals  highest_price  latitude  longitude  lowest_price  \
# 0   2018-11-28         NaN            NaN        40        -83           NaN
# 1   2018-12-08         NaN            NaN        36        -84           NaN
# 2   2018-12-15         NaN            NaN        30        -86           NaN
# 3   2018-12-28         NaN          584.0        40        -83         114.0
# 4   2018-12-29         NaN          584.0        41        -85          58.0
#
#                   venue      city
# 0  skully's-music-diner  Columbus
# 1  skully's-music-diner  Columbus
# 2  skully's-music-diner  Columbus
# 3  skully's-music-diner  Columbus
# 4  skully's-music-diner  Columbus

# %% [markdown]
# # 1.4 Import data from City

# %%
#Population Data
city = pd.read_csv("us_city_population.csv")
city["City"] = city['City'].str.split(',').str[0]
city["City"] = city['City'].str.split(' ').str[:-1]

def turn_string(row):
    city_string = ''.join(row["City"])
    return city_string
    

city["city"] = city.apply(lambda row: turn_string(row), axis=1)
city = city.drop(columns = ["City", "Index"])
print(city.shape)
city.head()
# Out:
# (769, 2)
#    Population_Estimate_2017        city
# 0                   8622698     NewYork
# 1                   3999759  LosAngeles
# 2                   2716450     Chicago
# 3                   2312717     Houston
# 4                   1626078     Phoenix

# %% [markdown]
# # 2. Aggregate data

# %% [markdown]
# # 2.1 Merge Last.fm Artists and Seatgeek Artists

# %%
lastfm_seatgeek = pd.merge(artists, lastfm, on='artist')
#lastfm_seatgeek = lastfm_seatgeek.drop(columns = ['artist_name'],axis = 1)

print(lastfm_seatgeek.shape)
lastfm_seatgeek.head()
# Out:
# (5924, 4)
#          artist                              genres concert_popularity  \
# 0  taylor-swift              country/pop/rock/folk/               0.89
# 1    charli-xcx                           pop/rock/               0.88
# 2    ed-sheeran                      pop/rock/folk/               0.88
# 3   snow-patrol  pop/rock/alternative/classic-rock/               0.88
# 4  eric-clapton        pop/rock/blues/classic-rock/               0.87
#
#    playcount
# 0  160372057
# 1   26468108
# 2   81588932
# 3   88180099
# 4   50222194

# %% [markdown]
# # 2.2 Merge Artist Info and Seatgeek Concert Info

# %%
dataset = pd.merge(total_concerts, lastfm_seatgeek, on='artist')
dataset.sort_values("concert_popularity", ascending=False,inplace=True)
dataset = dataset.drop(columns = ["good_deals"])
print(dataset.shape)
dataset.head()
# Out:
# (15592, 13)
#                                             address        artist  \
# 12493       2 Beasley Avenue, Auckland, New Zealand  taylor-swift
# 12492       2 Beasley Avenue, Auckland, New Zealand  taylor-swift
# 4001   1500 Sugar Bowl Drive, New Orleans, LA 70112    ed-sheeran
# 11944  1500 Sugar Bowl Drive, New Orleans, LA 70112   snow-patrol
# 11953      Hoffnigstrasse 1, Dubendorf, Switzerland   snow-patrol
#
#        average_price concert_date  highest_price  latitude  longitude  \
# 12493         1491.0   2018-11-19         2103.0        36        140
# 12492          656.0   2018-11-08          950.0       -37        175
# 4001           196.0   2018-11-08         1327.0        28        -83
# 11944          120.0   2018-11-01          608.0        30        -90
# 11953          201.0   2019-04-25          584.0        34        -84
#
#        lowest_price                    venue        city  \
# 12493         968.0         mt-smart-stadium    Auckland
# 12492         185.0         mt-smart-stadium    Auckland
# 4001           49.0  mercedes-benz-superdome  NewOrleans
# 11944          40.0  mercedes-benz-superdome  NewOrleans
# 11953         100.0             samsung-hall   Dubendorf
#
#                                    genres concert_popularity  playcount
# 12493              country/pop/rock/folk/               0.89  160372057
# 12492              country/pop/rock/folk/               0.89  160372057
# 4001                       pop/rock/folk/               0.88   81588932
# 11944  pop/rock/alternative/classic-rock/               0.88   88180099
# 11953  pop/rock/alternative/classic-rock/               0.88   88180099

# %% [markdown]
# # 2.3 Merge Concert Info and City Info

# %%
dataset = pd.merge(dataset, city, on='city')
print(dataset.shape)
dataset.head()
# Out:
# (12934, 14)
#                                         address       artist  average_price  \
# 0  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran          196.0
# 1  1500 Sugar Bowl Drive, New Orleans, LA 70112  snow-patrol          120.0
# 2  1500 Sugar Bowl Drive, New Orleans, LA 70112  snow-patrol          346.0
# 3  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran          119.0
# 4  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran        83510.0
#
#   concert_date  highest_price  latitude  longitude  lowest_price  \
# 0   2018-11-08         1327.0        28        -83          49.0
# 1   2018-11-01          608.0        30        -90          40.0
# 2   2018-11-04         1750.0        30        -95         113.0
# 3   2018-11-01          950.0        30        -90          36.0
# 4   2018-11-04     12148781.0        30        -95         139.0
#
#                      venue        city                              genres  \
# 0  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
# 1  mercedes-benz-superdome  NewOrleans  pop/rock/alternative/classic-rock/
# 2  mercedes-benz-superdome  NewOrleans  pop/rock/alternative/classic-rock/
# 3  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
# 4  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
#
#   concert_popularity  playcount  Population_Estimate_2017
# 0               0.88   81588932                    393292
# 1               0.88   88180099                    393292
# 2               0.88   88180099                    393292
# 3               0.88   81588932                    393292
# 4               0.88   81588932                    393292

# %%
market_heat = dataset.groupby(by = "city", as_index = False)["artist"].count().reset_index()
market_heat = market_heat.drop(columns = "index")
market_heat.columns = ["city", "market_heat"]
print(market_heat.shape)
market_heat.head()
# Out:
# (296, 2)
#           city  market_heat
# 0        Akron           28
# 1       Albany           57
# 2  Albuquerque           38
# 3   Alexandria           39
# 4        Allen            8

# %%
dataset = pd.merge(dataset, market_heat, on='city')
print(dataset.shape)
dataset.head()
# Out:
# (12934, 15)
#                                         address       artist  average_price  \
# 0  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran          196.0
# 1  1500 Sugar Bowl Drive, New Orleans, LA 70112  snow-patrol          120.0
# 2  1500 Sugar Bowl Drive, New Orleans, LA 70112  snow-patrol          346.0
# 3  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran          119.0
# 4  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran        83510.0
#
#   concert_date  highest_price  latitude  longitude  lowest_price  \
# 0   2018-11-08         1327.0        28        -83          49.0
# 1   2018-11-01          608.0        30        -90          40.0
# 2   2018-11-04         1750.0        30        -95         113.0
# 3   2018-11-01          950.0        30        -90          36.0
# 4   2018-11-04     12148781.0        30        -95         139.0
#
#                      venue        city                              genres  \
# 0  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
# 1  mercedes-benz-superdome  NewOrleans  pop/rock/alternative/classic-rock/
# 2  mercedes-benz-superdome  NewOrleans  pop/rock/alternative/classic-rock/
# 3  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
# 4  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
#
#   concert_popularity  playcount  Population_Estimate_2017  market_heat
# 0               0.88   81588932                    393292          125
# 1               0.88   88180099                    393292          125
# 2               0.88   88180099                    393292          125
# 3               0.88   81588932                    393292          125
# 4               0.88   81588932                    393292          125

# %% [markdown]
# # 2.4 Drop NAs

# %%
dataset = dataset.dropna()
print(dataset.shape)
dataset.head()
# Out:
# (9594, 15)
#                                         address       artist  average_price  \
# 0  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran          196.0
# 1  1500 Sugar Bowl Drive, New Orleans, LA 70112  snow-patrol          120.0
# 2  1500 Sugar Bowl Drive, New Orleans, LA 70112  snow-patrol          346.0
# 3  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran          119.0
# 4  1500 Sugar Bowl Drive, New Orleans, LA 70112   ed-sheeran        83510.0
#
#   concert_date  highest_price  latitude  longitude  lowest_price  \
# 0   2018-11-08         1327.0        28        -83          49.0
# 1   2018-11-01          608.0        30        -90          40.0
# 2   2018-11-04         1750.0        30        -95         113.0
# 3   2018-11-01          950.0        30        -90          36.0
# 4   2018-11-04     12148781.0        30        -95         139.0
#
#                      venue        city                              genres  \
# 0  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
# 1  mercedes-benz-superdome  NewOrleans  pop/rock/alternative/classic-rock/
# 2  mercedes-benz-superdome  NewOrleans  pop/rock/alternative/classic-rock/
# 3  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
# 4  mercedes-benz-superdome  NewOrleans                      pop/rock/folk/
#
#   concert_popularity  playcount  Population_Estimate_2017  market_heat
# 0               0.88   81588932                    393292          125
# 1               0.88   88180099                    393292          125
# 2               0.88   88180099                    393292          125
# 3               0.88   81588932                    393292          125
# 4               0.88   81588932                    393292          125

# %% [markdown]
# # 3. Separate Data into Test and Train
# Here we used train_test_split to split the dataset into two samples, namely 80% training and 20% testing.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=0.2, shuffle = True)

# %%
train = train.dropna()
print(train.shape)
train.head()
# Out:
# (7675, 15)
#                                                  address        artist  \
# 2481   2135 Queens Chapel Road Northeast, Washington,...        snails
# 3029        722 East Burnside Street, Portland, OR 97214   whitechapel
# 4775          3790 Wilshire Blvd., Los Angeles, CA 90010   jorja-smith
# 10136              6161 Delmar Blvd, St. Louis, MO 63112  julien-baker
# 12335           1875 Newport Blvd., Costa Mesa, CA 92627       slushii
#
#        average_price concert_date  highest_price  latitude  longitude  \
# 2481           120.0   2018-12-09          584.0        45        -93
# 3029           131.0   2018-12-13          584.0        30        -98
# 4775            96.0   2018-12-12          584.0        39        -77
# 10136          101.0   2018-11-28          580.0        38       -122
# 12335           21.0   2018-12-23           24.0        33       -117
#
#        lowest_price                   venue        city  \
# 2481           60.0               echostage  Washington
# 3029           46.0  the-bossanova-ballroom    Portland
# 4775           50.0             the-wiltern  LosAngeles
# 10136          51.0             the-pageant    St.Louis
# 12335          18.0          time-nightclub   CostaMesa
#
#                                 genres concert_popularity  playcount  \
# 2481                electronic/techno/               0.48     250992
# 3029   pop/rock/alternative/hard-rock/               0.44   11648404
# 4775                         soul/rnb/               0.65    2977461
# 10136                rock/alternative/               0.48    3156749
# 12335               electronic/techno/               0.46     524225
#
#        Population_Estimate_2017  market_heat
# 2481                     693972          379
# 3029                      66882          478
# 4775                    3999759          596
# 10136                    308626           83
# 12335                    113825           13

# %%
train.describe()
# Out:
#        average_price  highest_price     latitude    longitude  lowest_price  \
# count    7675.000000   7.675000e+03  7675.000000  7675.000000   7675.000000
# mean      234.175505   4.189519e+03    38.183062   -94.927948     95.963127
# std      1089.807231   1.969146e+05     5.310159    17.622408    158.951415
# min        13.000000   1.300000e+01    10.000000  -158.000000      6.000000
# 25%       108.000000   5.620000e+02    34.000000  -115.000000     49.000000
# 50%       148.000000   5.840000e+02    39.000000   -90.000000     66.000000
# 75%       232.000000   6.290000e+02    42.000000   -80.000000     98.000000
# max     83510.000000   1.225002e+07    61.000000     9.000000   5913.000000
#
#           playcount  Population_Estimate_2017  market_heat
# count  7.675000e+03              7.675000e+03  7675.000000
# mean   1.242393e+07              9.790858e+05   212.547101
# std    2.570890e+07              1.613363e+06   177.800802
# min    1.385100e+04              4.792900e+04     1.000000
# 25%    1.191805e+06              1.850380e+05    58.000000
# 50%    3.643560e+06              4.862900e+05   157.000000
# 75%    1.230564e+07              8.791700e+05   350.000000
# max    2.738279e+08              8.622698e+06   596.000000

# %%
test.describe()
# Out:
#        average_price  highest_price     latitude    longitude  lowest_price  \
# count    1919.000000    1919.000000  1919.000000  1919.000000   1919.000000
# mean      221.936946    1091.900469    38.083898   -94.517978     98.337676
# std       486.945870    4609.240653     5.311245    17.453037    321.897903
# min        13.000000      13.000000    18.000000  -158.000000      9.000000
# 25%       106.000000     559.000000    34.000000  -115.000000     48.000000
# 50%       147.000000     584.000000    39.000000   -88.000000     64.000000
# 75%       229.000000     619.000000    42.000000   -80.000000     97.000000
# max     12314.000000  179913.000000    55.000000   -67.000000  12314.000000
#
#           playcount  Population_Estimate_2017  market_heat
# count  1.919000e+03              1.919000e+03  1919.000000
# mean   1.142833e+07              9.421288e+05   213.569046
# std    2.446398e+07              1.549252e+06   177.891920
# min    2.911900e+04              4.792900e+04     1.000000
# 25%    1.112298e+06              1.940580e+05    56.500000
# 50%    3.187672e+06              4.862900e+05   157.000000
# 75%    1.095587e+07              7.247450e+05   350.000000
# max    2.738279e+08              8.622698e+06   596.000000

# %%
path = "train_final.csv"
train.to_csv(path_or_buf = path)

# %%
test = test.dropna()
print(test.shape)
test.head()
# Out:
# (1919, 15)
#                                                  address         artist  \
# 2085           287 Tampa Avenue South, Orlando, FL 32805        gryffin
# 8875                 68 Commerce, Grand Rapids, MI 49503   mewithoutyou
# 11647      125 West Jefferson Blvd, Fort Wayne, IN 46802  joe-bonamassa
# 12760  104 North Commercial Street, Bellingham, WA 98225     john-hiatt
# 5855              3200 Commerce Street, Dallas, TX 75226         clozee
#
#        average_price concert_date  highest_price  latitude  longitude  \
# 2085           471.0   2018-12-01        14413.0        34       -118
# 8875           108.0   2018-11-07          584.0        46       -123
# 11647          257.0   2018-11-08          889.0        40        -83
# 12760          198.0   2019-02-24          755.0        40        -75
# 5855           135.0   2018-12-29          584.0        54       -114
#
#        lowest_price                venue         city  \
# 2085           73.0         tinker-field      Orlando
# 8875           44.0   the-pyramid-scheme  GrandRapids
# 11647         106.0      embassy-theatre    FortWayne
# 12760          98.0  mount-baker-theatre   Bellingham
# 5855           57.0   deep-ellum-art-co.       Dallas
#
#                               genres concert_popularity  playcount  \
# 2085              electronic/techno/               0.57    1183814
# 8875           pop/rock/alternative/               0.44   16658388
# 11647  rock/blues/jazz/classic-rock/               0.57    9520940
# 12760         country/pop/rock/folk/               0.44    2992062
# 5855              electronic/techno/               0.49     387276
#
#        Population_Estimate_2017  market_heat
# 2085                     280257          164
# 8875                     198829           76
# 11647                    265904           24
# 12760                     89045            7
# 5855                    1341075          279

# %%
path = "test_final.csv"
test.to_csv(path_or_buf = path)
